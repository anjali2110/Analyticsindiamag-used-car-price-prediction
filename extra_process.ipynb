# %%
import pandas as pd
import numpy as np

df= pd.read_excel('Data_Train.xlsx')
df.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price
# 0        NaN   1.75
# 1        NaN  12.50
# ...

# %%
df=df.drop('New_Price', 1)
df.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    Price
# 0   1.75
# 1  12.50
# 2   4.50
# 3   6.00
# 4  17.74

# %%
df.isna().sum()
# Out:
# Name                  0
# Location              0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type            0
# Mileage               2
# Engine               36
# Power                36
# Seats                42
# Price                 0
# dtype: int64

# %%
not_null = df.dropna()
not_null.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    Price
# 0   1.75
# 1  12.50
# 2   4.50
# 3   6.00
# 4  17.74

# %%
dff= not_null.groupby(['Year'])['Price'].mean()
dff
# Out:
# Year
# 1998     1.432500
# 1999     0.835000
# 2000     1.175000
# 2001     1.664286
# 2002     1.254286
# 2003     1.631333
# 2004     1.956897
# 2005     2.039636
# 2006     3.414133
# 2007     3.217886
# 2008     3.553609
# 2009     5.206071
# 2010     5.546313
# 2011     6.852234
# 2012     7.312028
# 2013     8.694275
# 2014     9.635774
# 2015    11.241916
# 2016    11.717365
# 2017    13.781724
# 2018    15.726141
# 2019    19.464118
# Name: Price, dtype: float64

# %%
#mileage is replace with mean values

# for mileage name 
new = df["Mileage"].str.split(" ", n = 1, expand = True) 
df["Mileage"]= new[0] 
df.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type Mileage   Engine      Power  Seats  Price
# 0       CNG       Manual      First    26.6   998 CC  58.16 bhp    5.0   1.75
# 1    Diesel       Manual      First   19.67  1582 CC  126.2 bhp    5.0  12.50
# 2    Petrol       Manual      First    18.2  1199 CC   88.7 bhp    5.0   4.50
# 3    Diesel       Manual      First   20.77  1248 CC  88.76 bhp    7.0   6.00
# 4    Diesel    Automatic     Second    15.2  1968 CC  140.8 bhp    5.0  17.74

# %%
df.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage               object
# Engine                object
# Power                 object
# Seats                float64
# Price                float64
# dtype: object

# %%
df['Mileage']=pd.to_numeric(df['Mileage'],errors='coerce')

# %%
df.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage              float64
# Engine                object
# Power                 object
# Seats                float64
# Price                float64
# dtype: object

# %%
dff= df.groupby(['Year'])['Mileage'].mean().reset_index()
dff
# Out:
#     Year    Mileage
# 0   1998  14.900000
# 1   1999  15.150000
# 2   2000  15.267500
# 3   2001  10.900000
# 4   2002  12.126667
# 5   2003  14.670588
# 6   2004  12.483226
# 7   2005  13.090351
# 8   2006  14.485256
# 9   2007  14.730800
# 10  2008  15.240345
# 11  2009  15.367576
# 12  2010  16.313889
# 13  2011  16.845677
# 14  2012  18.045345
# 15  2013  18.449507
# 16  2014  18.852158
# 17  2015  19.184637
# 18  2016  19.633081
# 19  2017  19.412709
# 20  2018  19.314228
# 21  2019  17.834510

# %%
null_val=df[df['Mileage'].isnull()]
null_val
# Out:
#                            Name Location  Year  Kilometers_Driven Fuel_Type  \
# 4446       Mahindra E Verito D4  Chennai  2016              50000  Electric
# 4904  Toyota Prius 2009-2016 Z4   Mumbai  2011              44000  Electric
#
#      Transmission Owner_Type  Mileage   Engine   Power  Seats  Price
# 4446    Automatic      First      NaN    72 CC  41 bhp    5.0  13.00
# 4904    Automatic      First      NaN  1798 CC  73 bhp    5.0  12.75

# %%
null_val.loc[dee['Year'] == 2011, 'Mileage'] =16.845677
null_val.loc[dee['Year'] == 2016, 'Mileage'] =19.633081
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_setitem_indexer(self, key)
#     174         try:
# --> 175             return self._convert_to_indexer(key, is_setter=True)
#     176         except TypeError as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1153                 key = self._convert_for_reindex(key, axis)
# -> 1154             indexer = ax.get_indexer_for(key)
# ...

# %%
null_val.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3c33642832d7> in <module>
# ----> 1 null_val.tail()
#
# NameError: name 'null_val' is not defined
